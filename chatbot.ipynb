# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
from langchain.chat_models import init_chat_model

# %%
llm = init_chat_model("gemini-2.0-flash")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 llm = init_chat_model("gemini-2.0-flash")
#
# File ~/Documents/Personal Projects/langchain-start/venv/lib/python3.14/site-packages/langchain/chat_models/base.py:311, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     303     warnings.warn(
#     304         f"{config_prefix=} has been set but no fields are configurable. Set "
#     305         f"`configurable_fields=(...)` to specify the model params that are "
#     306         f"configurable.",
#     307         stacklevel=2,
#     308     )
#     310 if not configurable_fields:
# --> 311     return _init_chat_model_helper(
#     312         cast("str", model),
#     313         model_provider=model_provider,
#     314         **kwargs,
#     315     )
#     316 if model:
#     317     kwargs["model"] = model
#
# File ~/Documents/Personal Projects/langchain-start/venv/lib/python3.14/site-packages/langchain/chat_models/base.py:360, in _init_chat_model_helper(model, model_provider, **kwargs)
#     358     return ChatCohere(model=model, **kwargs)
#     359 if model_provider == "google_vertexai":
# --> 360     _check_pkg("langchain_google_vertexai")
#     361     from langchain_google_vertexai import ChatVertexAI
#     363     return ChatVertexAI(model=model, **kwargs)
#
# File ~/Documents/Personal Projects/langchain-start/venv/lib/python3.14/site-packages/langchain/chat_models/base.py:520, in _check_pkg(pkg, pkg_kebab)
#     518 pkg_kebab = pkg_kebab if pkg_kebab is not None else pkg.replace("_", "-")
#     519 msg = f"Unable to import {pkg}. Please install with `pip install -U {pkg_kebab}`"
# --> 520 raise ImportError(msg)
#
# ImportError: Unable to import langchain_google_vertexai. Please install with `pip install -U langchain-google-vertexai`
